# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/MineracaoDados/blob/main/atividades/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


dados = {
    "motor": ["M001", "M001", "M001", "M001", "M001",
              "M002", "M002", "M002", "M002", "M002"],
    "data_hora": [
        "2026-01-01 08:00",
        "2026-01-01 09:00",
        "2026-01-01 10:00",
        "2026-01-01 11:00",
        "2026-01-01 12:00",
        "2026-01-01 08:00",
        "2026-01-01 09:00",
        "2026-01-01 10:00",
        "2026-01-01 11:00",
        "2026-01-01 12:00"
    ],
    "corrente": [12.4, 12.8, 13.7, 15.2, 15.8, 10.8, 11.0, 11.2, 11.5, 11.7],
    "tensao": [380, 379, 381, 378, 377, 380, 381, 380, 379, 380],
    "vibracao": [1.8, 2.1, 3.4, 5.8, 6.2, 1.2, 1.3, 1.4, 1.5, 1.6],
    "temperatura": [62.3, 64.1, 68.7, 76.4, 79.2, 55.1, 56.0, 56.8, 57.4, 58.2],
    "rpm": [1750, 1748, 1742, 1728, 1719, 1752, 1750, 1749, 1748, 1747],
    "potencia": [7.2, 7.4, 8.1, 9.2, 9.6, 6.1, 6.2, 6.3, 6.4, 6.5],
    "horas_operacao": [1250, 1251, 1252, 1253, 1254, 820, 821, 822, 823, 824],
    "status": ["Normal", "Normal", "Alerta", "Falha", "Falha",
               "Normal", "Normal", "Normal", "Normal", "Normal"]
}

df = pd.DataFrame(dados)

df

# Visualizar as primeiras linhas
#df.head()

# Visualizar as últimas linhas
#df.tail()

# Informações sobre o DataFrame
#df.info()

# Estatísticas descritivas
#df.describe()
# Out:
#   motor         data_hora  corrente  tensao  vibracao  temperatura   rpm  \
# 0  M001  2026-01-01 08:00      12.4     380       1.8         62.3  1750
# 1  M001  2026-01-01 09:00      12.8     379       2.1         64.1  1748
# 2  M001  2026-01-01 10:00      13.7     381       3.4         68.7  1742
# 3  M001  2026-01-01 11:00      15.2     378       5.8         76.4  1728
# 4  M001  2026-01-01 12:00      15.8     377       6.2         79.2  1719
# 5  M002  2026-01-01 08:00      10.8     380       1.2         55.1  1752
# 6  M002  2026-01-01 09:00      11.0     381       1.3         56.0  1750
# 7  M002  2026-01-01 10:00      11.2     380       1.4         56.8  1749
# 8  M002  2026-01-01 11:00      11.5     379       1.5         57.4  1748
# 9  M002  2026-01-01 12:00      11.7     380       1.6         58.2  1747
#
#    potencia  horas_operacao  status
# 0       7.2            1250  Normal
# 1       7.4            1251  Normal
# 2       8.1            1252  Alerta
# 3       9.2            1253   Falha
# 4       9.6            1254   Falha
# 5       6.1             820  Normal
# 6       6.2             821  Normal
# 7       6.3             822  Normal
# 8       6.4             823  Normal
# 9       6.5             824  Normal
